# %%
import tomotopy as tp 
import numpy as np 
import matplotlib.pyplot as plt 
import matplotlib.colors as mcolors 
import re 
import json 

corpus = tp.utils.Corpus()
dictionary = json.load(open("preprocessing/preprocessing.json"))
for key, value in dictionary.items():
    for index, key in enumerate(value): 
        corpus.add_doc(value) # , numeric_metadata=[index], metadata=value)    
mdl = tp.GDMRModel(tw=tp.TermWeight.ONE, 
                   k=30, 
                   degrees=[6], 
                   alpha=1e-2, 
                   sigma=0.25, 
                   sigma0=3.0, 
                   decay=1.0,
                   #  metadata_range=[(2000, 2017)], 
                    corpus=corpus
)
mdl.optim_interval = 20
mdl.burn_in = 200

mdl.train(1000)

print('Num docs:{}, Num Vocabs:{}, Total Words:{}'.format(
    len(mdl.docs), len(mdl.used_vocabs), mdl.num_words
))

# Let's train the model
mdl.train(1000, show_progress=True)
mdl.summary()

# Let's visualize the result
topic_counts = mdl.get_count_by_topics()
lambdas = mdl.lambdas
lambdas = lambdas.reshape(lambdas.shape[:1] + (len(mdl.metadata_dict), -1))
# lambdas shape: [num_topics, num_categorical_metadata, degrees + 1]

md_range = mdl.metadata_range
r = np.stack([mdl.tdf_linspace(
    [md_range[0][0]], 
    [md_range[0][1]], 
    [50], # interpolation size
    cat
) for cat in mdl.metadata_dict])
# r shape: [num_categorical_metadata, 50, num_topics]

xs = np.linspace(*md_range[0], 50)
for k in (-topic_counts).argsort():
    print('Topic #{} ({})'.format(k, topic_counts[k]))
    print(*(w for w, _ in mdl.get_topic_words(k)))
    print('Lambda:', lambdas[k].reshape((len(mdl.metadata_dict), -1)))

    for label, ys in zip(mdl.metadata_dict, r[:, :, k]):
        label = re.sub(r'^(Proceedings|Journal)( of)?( the)?( -)?|International Conference on', '', label).strip()
        if len(label) >= 35: label = label[:33] + '...'
        plt.plot(xs, ys, linewidth=2, label=label)
    plt.title('#{}\n({})'.format(k, ' '.join(w for w, _ in mdl.get_topic_words(k, top_n=5))))
    plt.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: bad argument type for built-in operation
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 13
#      11     for index, key in enumerate(value):
#      12         corpus.add_doc(value, numeric_metadata=[index], metadata=value)
# ---> 13 mdl = tp.GDMRModel(tw=tp.TermWeight.ONE,
#      14                    k=30,
#      15                    degrees=[6],
#      16                    alpha=1e-2,
#      17                    sigma=0.25,
#      18                    sigma0=3.0,
#      19                    decay=1.0,
#      20                     metadata_range=[(2000, 2017)],
#      21                     corpus=corpus
#      22 )
#      23 mdl.optim_interval = 20
#      24 mdl.burn_in = 200
#
# ValueError: Since version 0.11.0, `GDMRModel` requires a `metadata` value in `str` type. You can store numerical metadata to a `numeric_metadata` argument. (given ['twee', 'kamer', 'statengeneraal', 'vergaderjaar', 'aanhangsel', 'handeling', 'kamer', 'regering', 'becker', 'michonderkz', 'vvd', 'minister', 'justitie', 'veiligheid', 'staatssecretaris', 'zaak', 'werkgelegenheid', 'kaasfabriek', 'marokko', 'Nederlands', 'subsidie', 'deradicalisering', 'januari', 'minister', 'weel', 'justitie', 'veiligheid', 'staatssecretaris', 'zaak', 'werkgelegenheid', 'aanhangsel', 'handeling', 'vergaderjaar', 'nummer', 'artikel', 'marokko', 'kaasfabriek', 'Nederlands', 'subsidie', 'deradicalisering', 'n', 'mislei', 'periode', 'stichting', 'Rotterdam', 'platform', 'buitenlander', 'Rijnmond', 'subsidie', 'deradicaliseringsaanpak', 'Enof', 'integratie', 'kaasfabriek', 'marokko', 'minister', 'justitie', 'veiligheid', 'strafzaken', 'gemeente', 'Rotterdam', 'subsidie', 'één', 'instantie', 'damse', 'gemeenteraad', 'persbericht', 'ministerie', 'fraud', 'aantal', 'stichting', 'feit', 'periode', 'stichting', 'project', 'integratie', 'reintegratie', 'preventie', 'radicalisering', 'nrc', 'januari', 'opgezetmetnederlandsesubsidiesvoorderadicaliseringhetlijkteengrotemisleiding', 'onderzoeknaarstichtingenwegensmogelijkefraud', 'ahtk', 'issn', 'sgravenhage', 'twee', 'kamer', 'vergaderjaar', 'aanhangsel', 'gemeente', 'Rotterdam', 'betrekken', 'stichting', 'kopie', 'één', 'gemeente', 'procesdossier', 'burgemeester', 'maatregel', 'betrekking', 'gemeente', 'subsidie', 'toelichting', 'beantwoording', 'gemeente', 'Rotterdam', 'collegebrief', 'februari', 'jl', 'gemeente', 'subsidieverstrekking', 'stichting', 'onregelmatighed', 'zaak', 'kopie', 'één', 'procesverbaal', 'gemeente', 'procesdossier', 'burgemeester', 'maatregel', 'betrekking', 'gemeente', 'subsidie', 'gemeente', 'hoofdofficier', 'justitie', 'arrondissementsparket', 'Rotterdam', 'driehoek', 'procesniveau', 'nformeren', 'stand', 'zaak', 'feit', 'gemeente', 'aangifte', 'feit', 'partij', 'basis', 'informatie', 'gemeente', 'gemeente', 'gesprek', 'informatie', 'februari', 'vervolging', 'ernst', 'stichting', 'drie', 'zitting', 'ombeschikking', 'drie', 'artikel', 'lid', 'wetboek', 'strafvordering', 'officier', 'justitie', 'omstrafbeschikking', 'zes', 'jaar', 'gevangenisstraf', 'omstrafbeschikking', 'rechtskarakter', 'veroordeling', 'strafbeschikking', 'daad', 'vervolging', 'geval', 'geldboet', 'taakstraffen', 'terechtzitting', 'isen', 'resultaat', 'gesprek', 'onderhandeling', 'advocaat', 'strafbe', 'schikking', 'dagvaarding', 'zaak', 'zitting', 'strafbeschikking', 'schuldvaststelling', 'strafblad', 'zaak', 'aantal', 'één', 'instantie', 'advocaat', 'afdoening', 'dagvaarding', 'afdoening', 'strafbeschikking', 'resultaat', 'ombeschikking', 'taakstraf', 'uur', 'boete', 'euro', 'persoon', 'schuldbekentenis', 'collegebrief', 'rvw', 'fraud', 'deradicaliseringsdeskundig', 'rotterdamraad', 'ibabs', 'publieksportaal', 'aanwijzing', 'omstrafbeschikking', 'twee', 'kamer', 'vergaderjaar', 'aanhangsel', 'schuldbekentenis', 'spraak', 'persbericht', 'werkstrafef', 'variren', 'uur', 'boete', 'variren', 'toelichting', 'ombeschikking', 'beantwoording', 'bestuurder', 'stichting', 'beroepsverbod', 'beroepsverbod', 'terechtzitting', 'isen', 'aantal', 'jaar', 'bestuurder', 'stichting', 'rechtbank', 'beroepsverbod', 'interventie', 'periode', 'bestuurder', 'beroepsverbod', 'werking', 'uitspraak', 'jaar', 'keuze', 'strafbeschikking', 'afdoeningsmodaliteit', 'strafzaak', 'feit', 'reden', 'beroepsverbod', 'platform', 'buitenlander', 'Rijnmond', 'statuut', 'stichting', 'Enof', 'bestuurder', 'stichting', 'platform', 'buitenlander', 'Rijnmond', 'pbr', 'naam', 'stichting', 'mesam', 'uittreksel', 'kamer', 'koophan', 'del', 'stichting', 'mesam', 'participatie', 'emancipatie', 'burger', 'aandacht', 'kwetsbaren', 'allochtonen', 'Nederlands', 'samenleving', 'einde', 'liquidatie', 'registratie', 'stichting', 'kvk', 'beindigen', 'platform', 'vijftien', ...
